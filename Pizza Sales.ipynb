# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ranah\\Desktop\\Pizza Sales\\pizza_sales.csv")

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.head(100)
# Out:
#     pizza_id  order_id   pizza_name_id  quantity  order_date order_time  \
# 0          1         1      hawaiian_m         1  01-01-2015   11:38:36
# 1          2         2   classic_dlx_m         1  01-01-2015   11:57:40
# 2          3         2   five_cheese_l         1  01-01-2015   11:57:40
# 3          4         2     ital_supr_l         1  01-01-2015   11:57:40
# 4          5         2      mexicana_m         1  01-01-2015   11:57:40
# ..       ...       ...             ...       ...         ...        ...
# 95        96        39     ital_supr_l         1  01-01-2015   17:07:23
# 96        97        40   four_cheese_l         1  01-01-2015   17:14:36
# 97        98        40    southw_ckn_s         1  01-01-2015   17:14:36
# 98        99        41   four_cheese_m         1  01-01-2015   17:15:20
# 99       100        41  green_garden_s         1  01-01-2015   17:15:20
#
#     unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
len(df)           # Total no of orders
# Out:
# 48620

# %%
df["quantity"].sum()        # Total Pizzas sold
# Out:
# 49574

# %%
df["total_price"].sum()         # Total revenue generated
# Out:
# 817860.05

# %%
# Number of pizzas sold accoring to size

# %%
df.groupby("pizza_size")["quantity"].sum()
# Out:
# pizza_size
# L      18956
# M      15635
# S      14403
# XL       552
# XXL       28
# Name: quantity, dtype: int64

# %%
# Number of pizzas sold according to category

# %%
df.groupby("pizza_category")["quantity"].sum()
# Out:
# pizza_category
# Chicken    11050
# Classic    14888
# Supreme    11987
# Veggie     11649
# Name: quantity, dtype: int64

# %%
# Revenue according to category

# %%
df.groupby("pizza_category")["total_price"].sum()
# Out:
# pizza_category
# Chicken    195919.50
# Classic    220053.10
# Supreme    208197.00
# Veggie     193690.45
# Name: total_price, dtype: float64

# %%
# Revenue according to Size

# %%
df.groupby("pizza_size")["total_price"].sum()
# Out:
# pizza_size
# L      375318.70
# M      249382.25
# S      178076.50
# XL      14076.00
# XXL      1006.60
# Name: total_price, dtype: float64

# %%
# No of pizzas sold according to size in each category

# %%
x = df.pivot_table(values='quantity', index='pizza_category', columns='pizza_size', aggfunc='sum', fill_value=0)
x
# Out:
# pizza_size         L     M     S   XL  XXL
# pizza_category
# Chicken         4932  3894  2224    0    0
# Classic         4057  4112  6139  552   28
# Supreme         4564  4046  3377    0    0
# Veggie          5403  3583  2663    0    0

# %%
# In the data we dont have XL and XXL sizes pizzas in supreme, chicken and veggie category.

# %%
# revenue generated by pizzas size in each category

# %%
y = df.pivot_table(values='total_price', index='pizza_category', columns='pizza_size', aggfunc='sum', fill_value=0)
y
# Out:
# pizza_size             L         M         S     XL     XXL
# pizza_category
# Chicken         102339.0  65224.50  28356.00      0     0.0
# Classic          74518.5  60581.75  69870.25  14076  1006.6
# Supreme          94258.5  66475.00  47463.50      0     0.0
# Veggie          104202.7  57101.00  32386.75      0     0.0

# %%
z = df.pivot_table(values='unit_price', index='pizza_category', columns='pizza_size',  fill_value=0)
z
# Out:
# pizza_size              L          M          S    XL    XXL
# pizza_category
# Chicken         20.750000  16.750000  12.750000   0.0   0.00
# Classic         18.376850  14.739122  11.375021  25.5  35.95
# Supreme         20.652837  16.429972  14.048149   0.0   0.00
# Veggie          19.295383  15.938485  12.161352   0.0   0.00
